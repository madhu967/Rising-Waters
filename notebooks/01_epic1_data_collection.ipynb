# %% [markdown]
# # Epic 1: Data Collection## Story 1: Download and load the flood prediction dataset

# %%
import osimport pandas as pdDATA_PATH = os.path.join("..", "data", "flood dataset.xlsx")df = pd.read_excel(DATA_PATH)print(f"Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")df.head()

# %%
df.info()

# %%
df.describe()
